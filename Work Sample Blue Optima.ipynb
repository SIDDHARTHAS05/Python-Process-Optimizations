# %% [markdown]
# # Query the number of changes by status

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_change.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('change',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT COUNT(*), ch_status FROM change GROUP BY ch_status")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#        0          1
# 0  10592  ABANDONED
# 1  38595     MERGED
# 2   8189        NEW

# %% [markdown]
# # Query all the review with -2 vote

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('history',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT * FROM history WHERE hist_message LIKE '%Do not submit%' OR hist_message LIKE '%Code-Review-2%'ORDER BY hist_createdTime ASC")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#            0                  1  \
# 0     435809  daeb3561_4120529b
# 1     435426  1a2f8d8d_115d0cea
# 2     435379  1a2f8d8d_a016e0ef
# 3     435266  1a2f8d8d_579fff03
# 4     376906  fa5d592f_aa192f24
# ...      ...                ...
# 1081  378772  baa041b7_ebf66c5c
# 1082     211  baa041b7_d2234cbd
# 1083     215  baa041b7_73c3583a
# 1084     548  baa041b7_6504a717
# 1085     138  9aa53dc9_7f4b6f2c
#
#                                                       2        3  \
# 0                 Patch Set 1: Code-Review-2 Verified-1  1000038
# 1     Patch Set 1: Code-Review-2 Verified-1\n\nrejected  1000786
# 2                            Patch Set 2: Code-Review-2  1000879
# 3     Patch Set 2: Code-Review-2\n\nWes... Implement...  1000585
# 4             Patch Set 8: Code-Review-2\n\ndon't merge  1000586
# ...                                                 ...      ...
# 1081              Patch Set 1: Code-Review-2 Verified-1  1008482
# ...

# %% [markdown]
# # Query all the review with -1 vote

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('history',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT * FROM history WHERE hist_message LIKE '%I would prefer that you%' OR hist_message LIKE '%Code-Review-1%' ORDER BY hist_createdTime ASC")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#             0                  1  \
# 0      378319  daeb3561_81741a9d
# 1       21193  ba092121_3809092d
# 2      435801  ba092121_d83d6dbd
# 3      435783  5a202591_35f3500c
# 4       21134  3a1d315d_3409102d
# ...       ...                ...
# 16424      41  9aa53dc9_dfd4bb48
# 16425      69  9aa53dc9_7f200f4a
# 16426      55  9aa53dc9_ffb9bfed
# 16427      34  9aa53dc9_1f4b43b2
# 16428       9  9aa53dc9_221a706f
#
#                                                        2        3  \
# 0                             Patch Set 1: Code-Review-1  1000038
# 1              Patch Set 1: Code-Review-1\n\n(1 comment)  1000394
# 2      Patch Set 1: Code-Review-1\n\n(1 comment)\n\nN...  1000264
# 3      Patch Set 1: Code-Review-1\n\nPlease add #!/us...  1000429
# 4      Patch Set 1: Code-Review-1\n\nFor a better cod...  1000546
# ...                                                  ...      ...
# 16424         Patch Set 1: Code-Review-1\n\n(3 comments)  1000777
# ...

# %% [markdown]
# # Query all the review with +1 vote

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('history',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT * FROM history WHERE hist_message LIKE '%Looks good to me, but someone else must approve%'OR hist_message LIKE '%Code-Review+1%'ORDER BY hist_createdTime ASC")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#             0                  1  \
# 0      378315  daeb3561_a15efe10
# 1      378283  3a045101_fc126957
# 2       21178  ba092121_f8f831c6
# 3      378252  5a202591_f5dcb876
# 4      378209  3a1d315d_74e9c819
# ...       ...                ...
# 19300      23  9aa53dc9_9f8753d7
# 19301   21270  9aa53dc9_df64bb4a
# 19302      24  9aa53dc9_9fd513bb
# 19303       8  9aa53dc9_ff49bf8f
# 19304   21271  9aa53dc9_1f2c63aa
#
#                                                        2        3  \
# 0                             Patch Set 1: Code-Review+1  1000038
# 1      Patch Set 1: Code-Review+1\n\n(1 comment)\n\nT...  1000191
# 2                     Patch Set 1: Code-Review+1\n\nNice  1000462
# 3                     Patch Set 1: Code-Review+1\n\ngood  1000429
# 4      Patch Set 1: Code-Review+1 Verified+1\n\nok, i...  1000552
# ...                                                  ...      ...
# 19300  Patch Set 1: Code-Review+1\n\nBuild Successful...  1009584
# ...

# %% [markdown]
# # Query all the core reviewers

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('history',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT distinct hist_authorAccountId FROM history WHERE hist_message LIKE '%Looks good to me, approved%'OR hist_message LIKE '%Code-Review+2%'OR hist_message LIKE '%Do not submit%'OR hist_message LIKE '%Code-Review-2%'ORDER BY hist_createdTime ASC")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#             0
# 0     1000038
# 1     1000039
# 2     1000054
# 3     1000394
# 4     1000407
# ...       ...
# 1077  1004185
# 1078  1002755
# 1079  1003555
# 1080  1008712
# 1081  1002751
#
# [1082 rows x 1 columns]

# %% [markdown]
# # How long does it take to get a code review merged?

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
import datetime
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_change.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('change',engine,if_exists = 'replace',index = False)
from datetime import datetime
date_format_str = '%d/%m/%Y %H:%M:%S.%f'
start = datetime.strptime(ch_createdTime, date_format_str)
end =   datetime.strptime(ch_updatedTime, date_format_str)
diff = end - start
# 
# WHERE ch_status IN ('Merged')
results = engine.execute("SELECT id,ch_authorAccountId,ch_createdTime,ch_updatedTime, TIMESTAMPDIFF(SECOND,ch_createdTime,ch_updatedTime) as difference FROM change where ch_status IN ('MERGED')")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
print(final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-979bd9e9a818> in <module>
#      10 from datetime import datetime
#      11 date_format_str = '%d/%m/%Y %H:%M:%S.%f'
# ---> 12 start = datetime.strptime(ch_createdTime, date_format_str)
#      13 end =   datetime.strptime(ch_updatedTime, date_format_str)
#      14 diff = end - start
#
# NameError: name 'ch_createdTime' is not defined

# %%
# Total number of distinct authors
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_people.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('people',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT distinct p_name,p_username from people")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#                       0              1
# 0         Alex Bikfalvi   alexbikfalvi
# 1          Midokura Bot       midosaba
# 2     Alexandre Fonseca         AlexJF
# 3         SergeySokolov  SergeySokolov
# 4      Mirantis Jenkins  qa-stepler-ci
# ...                 ...            ...
# 2527           Nick Orr      Biskelion
# 2528         Alex Pilon         MadMub
# 2529       michaelbrawn   michaelbrawn
# 2530    Daniel Nachbaur     tribal-tec
# 2531        Jay Soffian     jaysoffian
#
# [2532 rows x 2 columns]

# %% [markdown]
# # query with +2 votes

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('history',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT distinct hist_authorAccountId FROM history WHERE hist_message LIKE '%Looks good to me, approved%'OR hist_message LIKE '%Code-Review+2%'OR hist_message LIKE '%Do not submit%'OR hist_message LIKE '%Code-Review-2%'ORDER BY hist_createdTime ASC")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#             0
# 0     1000038
# 1     1000039
# 2     1000054
# 3     1000394
# 4     1000407
# ...       ...
# 1077  1004185
# 1078  1002755
# 1079  1003555
# 1080  1008712
# 1081  1002751
#
# [1082 rows x 1 columns]

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file1 = r'C:\Users\sddhr\Downloads\DA-WS-files\t_revision.xlsx'
file2 = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df1 = pd.read_excel(file1) 
df2 = pd.read_excel(file2)
df3 = pd.merge(df2,df1, left_on='hist_changeId', right_on ='rev_changeId',how = 'left',indicator = True)
print(df3)

# df1.to_sql('revision',engine,if_exists = 'replace',index = False)
# df2.to_sql('history',engine,if_exists = 'replace',index = False)
# results = engine.execute("SELECT h.id from revision r left join history h on h.hist_patchSetNum = r.rev_patchSetNum")
# final = pd.DataFrame(results)
# # final.to_excel(output,index = False)
# final

# %% [markdown]
# # number of lines inserted by id

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_file.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('file',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT f_revisionId,f_linesInserted from file group by f_revisionId")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
#            0   1
# 0          1   2
# 1          2  49
# 2          3   7
# 3          4   3
# 4          5   4
# ...      ...  ..
# 71766  72676   7
# 71767  72677   1
# 71768  72678  16
# 71769  72679  16
# 71770  72680  16
#
# [71771 rows x 2 columns]

# %%
# Append dataframe and create a new one
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file1 = r'C:\Users\sddhr\Downloads\DA-WS-files\t_revision.xlsx'
file2 = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df1 = pd.read_excel(file1) 
df2 = pd.read_excel(file2)
df3 = df1.append(df2)
print(df3.head(10))
# Out:
#    id                                    rev_id  \
# 0   1  663dd192a19e7ab1452668a3672fb467c8110e04
# 1   2  fc9090c70665a19c44037113d5e3631e2c238aa8
# 2   3  652ca44c9d1dfdf3880b0e4fd001daecaf95e383
# 3   4  54b36414dcd80606ba14f7dc2a9766b957fdca90
# 4   5  d61d7b3b46650f784a9b1bf78320430af874a238
# 5   6  a656fa1392bf37b475a17f7269ba2d50cc302efe
# 6   7  73550a2dfabfaa3e14d0d8ad637692390892bf94
# 7   8  087af68b9a6f4dbea85626dda8096e04332fb245
# 8   9  225a36e9d2ecd42f67b4624a1f049f466a9b5450
# 9  10  f664af0e0fad4de57cbdc0f70181675c54723f5a
#
#                                          rev_subject  \
# 0  Add IP subnet utility method for converting lists
# 1   Make FlowRecorder send records over TCP to Clio.
# 2   Add test to restart neutron l3 agent with SIGHUP
# 3                     LBaaS V2 Neutron API endpoints
# 4            Fix thread-unsafety with FlowRecorders.
# 5                                 Change neutron MTU
# 6                           Remove MTU related tasks
# ...

# %%
# author with maximum changes
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_change.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('change',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT distinct ch_authorAccountId,max(id) from change group by ch_authorAccountId")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final.head(10)
# Out:
#          0      1
# 0  1000000  57361
# 1  1000036   7249
# 2  1000038  57376
# 3  1000039  57373
# 4  1000052  57355
# 5  1000054  46779
# 6  1000066   7791
# 7  1000178   2049
# 8  1000191  57143
# 9  1000213   4791

# %% [markdown]
# # revision id count by author name

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file = r'C:\Users\sddhr\Downloads\DA-WS-files\t_revision.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df = pd.read_excel(file) 
df.to_sql('revision',engine,if_exists = 'replace',index = False)
results = engine.execute("SELECT distinct rev_authorUsername,max(id) from revision group by rev_authorUsername")
final = pd.DataFrame(results)
# final.to_excel(output,index = False)
final
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     589     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 590         cursor.executemany(statement, parameters)
#     591
#
# InterfaceError: Error binding parameter 2 - probably unsupported type.
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# ...

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
file1 = r'C:\Users\sddhr\Downloads\DA-WS-files\t_revision.xlsx'
file2 = r'C:\Users\sddhr\Downloads\DA-WS-files\t_history.xlsx'
output = 'output.xlsx'
engine = create_engine('sqlite://',echo = False)
df1 = pd.read_excel(file1) 
df2 = pd.read_excel(file2)
df3 = pd.DataFrame(df1, columns = ['rev_patchSetNum'])
# Out:
# <bound method Series.max of 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 122329    1.0
# 122330    1.0
# 122331    1.0
# 122332    1.0
# 122333    1.0
# Name: rev_patchSetNum, Length: 122334, dtype: float64>

# %% [markdown]
# # SQL QUERIES

# %%
# Maximum change in project

# which author has committed most number of changes

# which project has most number of changes

# which project has most number of revision

# which change has most number of revisions
